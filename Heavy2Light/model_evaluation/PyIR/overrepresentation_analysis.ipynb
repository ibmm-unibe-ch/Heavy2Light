# %%
from vgene_analyzer import VGeneAnalyzer, quick_analysis, compare_thresholds

# %%
analyzer = VGeneAnalyzer('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/pyir_output/overrepresented_gen_sequences_bert2gpt.json')
# Out:
# Loaded 2578 sequences from /ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/pyir_output/overrepresented_gen_sequences_bert2gpt.json

# %%
# Family distribution with custom styling
analyzer.plot_family_distribution(
    min_count=100,
    top_n=10,
    figsize=(8, 6),
    title_fontsize=18,
    label_fontsize=20,              # Axis labels (X/Y axis)
    bar_label_fontsize=9,
    tick_fontsize=13,               # Tick labels (family names, numbers on axes)
    bar_color='grey',
    save_path='/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/plots/overrepresented_genes/overrepresented_gen_sequences_bert2gpt.png'
)
# Out:
# Filtered to 61 sequences with count >= 100
# Plot saved to: /ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/plots/overrepresented_genes/overrepresented_gen_sequences_bert2gpt.png

# %%
detailed_results = analyzer.analyze_v_genes(min_count=100)
print(detailed_results)

# %%
# Get family-level summary
family_summary = analyzer.get_family_summary(min_count=100)
print(family_summary)

# %%
gene_summary = analyzer.get_gene_summary(min_count=100)
print(gene_summary)

# %%
analyzer.plot_family_distribution(min_count=100, top_n=10)
analyzer.plot_gene_distribution(min_count=100, top_n=15)

# %%
#analyzer.export_results(min_count=100, output_prefix='high_count_analysis')

# %%
from simple_v_gene_analyzer import SimpleVGeneAnalyzer, quick_family_analysis

# %%
analyzer = quick_family_analysis('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/pyir_output/bert2gpt_full_complete_ids.json')

# %%
analyzer = quick_family_analysis('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/train_val_test_fastas/plabdab_human_healthy_no_vac_allocated_test_no_identifiers.json')

# %%
analyzer = quick_family_analysis('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/train_val_test_fastas/plabdab_human_healthy_no_vac_allocated_train_no_identifiers.json')

# %%
analyzer = SimpleVGeneAnalyzer('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/pyir_output/bert2gpt_full_complete_ids.json')

# %%
analyzer.plot_family_distribution(
    figsize=(8, 6),
    title_fontsize=18,              # Title
    label_fontsize=20,              # Axis labels (X/Y axis)
    tick_fontsize=13,               # Tick labels (family names, numbers on axes)
    bar_label_fontsize=9,          # Count/percentage labels ON the bars
    bar_color="grey",          # Color of the bars
    save_path='/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/PyIR/plots/overrepresented_genes/v_genes_plabdab_human_healthy_no_vac_allocated_train_no_identifiers.png',
    dpi=600
)

# %%
#analyzer = SimpleVGeneAnalyzer('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/train_val_test_fastas/plabdab_human_healthy_no_vac_allocated_test_no_identifiers.json')

analyzer = SimpleVGeneAnalyzer('/ibmm_data2/oas_database/paired_lea_tmp/paired_model/unconditioned_gen_seqs/train_val_test_fastas/plabdab_human_healthy_no_vac_allocated_train_no_identifiers.json')
